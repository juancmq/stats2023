# %% [markdown]
# <a href="https://colab.research.google.com/github/juancmq/stats2023/blob/main/Monsalve_Stats_22_Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7fddc39bb580>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')  # this is how we display the data

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %%
cereal_data # With the previous definition to the equation we are able to display a different part of the data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"].mean() # this is how we get the mean of the sugar data
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean() # we are also able to get the mean of 2 different parts of the data like this
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
cereal_data[["calories", "sugars"]] # this is how we display specific parts of the data
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.') # this is how we graph specific data we got at the start

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y,'.') # this is why there are points in the graph
plt.plot(X, Y_pred, color='red') # this gives the line its red color
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

# %%
plt.plot(x,y,'.');

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.'); # this give the line points its red color
plt.plot(x,y,'g.'); #this give the points its green color

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.'); # this is what gives the line of dots its red color
plt.plot(x,y,'g.'); # this is how we make green dots

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
loss
# Out:
# 5976.090982893823

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess) # this is how we are able to run multiple simulations of guesses at the same time
# Out:
# 425763.9752476596 -10.0 -10.0
# 407644.3358786455 -10.0 -7.777777777777778
# 390018.5236701252 -10.0 -5.555555555555555
# 372886.5386220988 -10.0 -3.333333333333333
# 356248.38073456613 -10.0 -1.1111111111111107
# 340104.05000752746 -10.0 1.1111111111111107
# 324453.5464409825 -10.0 3.333333333333334
# 309296.87003493134 -10.0 5.555555555555557
# 294634.020789374 -10.0 7.777777777777779
# 280464.99870431056 -10.0 10.0
# 316339.1693079781 -7.777777777777778 -10.0
# 300688.66574143316 -7.777777777777778 -7.777777777777778
# 285531.98933538207 -7.777777777777778 -5.555555555555555
# 270869.1400898247 -7.777777777777778 -3.333333333333333
# 256700.11800476123 -7.777777777777778 -1.1111111111111107
# 243024.9230801916 -7.777777777777778 1.1111111111111107
# 229843.5553161158 -7.777777777777778 3.333333333333334
# 217156.01471253383 -7.777777777777778 5.555555555555557
# 204962.30126944566 -7.777777777777778 7.777777777777779
# 193262.4149868513 -7.777777777777778 10.0
# ...

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 97773.91323648309 -3.6842105263157894 3.6842105263157894
# 93893.91170096057 -3.6842105263157894 4.7368421052631575
# 90124.71348953777 -3.6842105263157894 5.789473684210526
# 86466.3186022147 -3.6842105263157894 6.842105263157894
# 82918.72703899133 -3.6842105263157894 7.894736842105264
# 79481.93879986771 -3.6842105263157894 8.94736842105263
# 76155.95388484378 -3.6842105263157894 10.0
# 73457.26924104763 -2.6315789473684212 3.6842105263157894
# 70131.28432602373 -2.6315789473684212 4.7368421052631575
# 66916.10273509954 -2.6315789473684212 5.789473684210526
# 63811.724468275075 -2.6315789473684212 6.842105263157894
# 60818.149525550325 -2.6315789473684212 7.894736842105264
# 57935.37790692532 -2.6315789473684212 8.94736842105263
# 55163.40961240002 -2.6315789473684212 10.0
# 52871.7575877457 -1.578947368421053 3.6842105263157894
# 50099.7892932204 -1.578947368421053 4.7368421052631575
# 47438.62432279483 -1.578947368421053 5.789473684210526
# ...
