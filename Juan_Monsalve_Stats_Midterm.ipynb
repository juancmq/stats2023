# %% [markdown]
# <a href="https://colab.research.google.com/github/juancmq/stats2023/blob/main/Juan_Monsalve_Stats_Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STA 2023 Midterm Project
#
# Directions:
#
# *   Use any and all resources available to you
# *   Comment and explain the code
# *   Answer the questions to the best of your abilities
# *   There are no points for pain: ask for help
#
# Save this notebook to your GitHub and submit the link.

# %%
import numpy as np # this will import the library and shorten it for when we have to write it
import matplotlib.pyplot as plt # this does the same thing as the one above but with a different library

# %% [markdown]
# ## Part 1: Getting your data
#
# Create a google form to input your data.
# Follow the same method as [Lab 5](https://colab.research.google.com/drive/1zYvyhrz2wVnJXlZqj_PpxOxplfS3LN9Y?usp=sharing).

# %%
import pandas as pd
def get_database(url): # This function loads the google spreadsheet
    url_head = "https://docs.google.com/spreadsheets/d/"
    url_foot = "/gviz/tq?tqx=out:csv&sheet="
    url_body = url.split('/')[5]
    sheet_name = "1"
    url_csv = url_head + url_body + url_foot + sheet_name
    df = pd.read_csv(url_csv, sep=',', skiprows=0)
    return df

# %% [markdown]
# Put your form url here:

# %% [markdown]
# ![Diameter Circumference.PNG](data:image/png;base64,...)

# %%
circumferences = 5,8,15,3,7
diameters = 15,26,60,12,24

# %% [markdown]
# Plot your data points

# %%
X = np.array([12,9,20,7,2]) # this is where we put our diameter
Y = np.array([38,28,63,22,6]) # this is where we put our circumference

# %%
plt.title("Circle Diameter vs Circumference") #this is how we title our graph

plt.xlabel("Circumference") #this is how we title our X-axis
plt.ylabel("Diameter") #this is how we title our Y-axis

plt.plot(X,Y,'g.'); # this is how we plot our points and make them a specific shape and color

# %% [markdown]
# ## Part 2: Linear Fit
#
# Follow the steps in the [Linear Fit notebook]() to run a linear fit on your data.

# %% [markdown]
# $y = mx + b$

# %%
x = X
y = Y

# %%
m_guess = 0
b_guess = 0 # this is how we take a guess which in this case is 0

# %%
x
# Out:
# array([12,  9, 20,  7,  2])

# %%
m_guess * x #this is equal to the equation m*x
# Out:
# array([0, 0, 0, 0, 0])

# %%
m_guess * X + b_guess # there is a zero for every output we put in because of our first guess
# Out:
# array([0, 0, 0, 0, 0])

# %%
y_guess = m_guess * X + b_guess #this is an approximation of the y=mx+b formula

# %%
y_guess - Y # this is how far off we were from our actual data
# Out:
# array([-38, -28, -63, -22,  -6])

# %%
y_guess
# Out:
# array([0, 0, 0, 0, 0])

# %%
best_loss = 1000000000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-100,100,100):
    for b_guess in np.linspace(-100,100,100):

        print("Now Testing: ", m_guess, b_guess) #this is what we want it to say before the guesses
        
        y_guess = m_guess * x + b_guess #again this is the y=mx+b equation

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess
# Out:
# Streaming output truncated to the last 5000 lines.
# Now Testing:  1.0101010101010104 -100.0
# Now Testing:  1.0101010101010104 -97.97979797979798
# Now Testing:  1.0101010101010104 -95.95959595959596
# Now Testing:  1.0101010101010104 -93.93939393939394
# Now Testing:  1.0101010101010104 -91.91919191919192
# Now Testing:  1.0101010101010104 -89.8989898989899
# Now Testing:  1.0101010101010104 -87.87878787878788
# Now Testing:  1.0101010101010104 -85.85858585858585
# Now Testing:  1.0101010101010104 -83.83838383838383
# Now Testing:  1.0101010101010104 -81.81818181818181
# Now Testing:  1.0101010101010104 -79.79797979797979
# Now Testing:  1.0101010101010104 -77.77777777777777
# Now Testing:  1.0101010101010104 -75.75757575757575
# Now Testing:  1.0101010101010104 -73.73737373737373
# Now Testing:  1.0101010101010104 -71.71717171717171
# Now Testing:  1.0101010101010104 -69.69696969696969
# Now Testing:  1.0101010101010104 -67.67676767676767
# ...

# %%
y_guess = best_m * x + best_b

plt.plot(x,y_guess,'r'); #this is how we plot our best approximations, this will plot it with a red line
plt.plot(X,Y,'g.'); # this will plot it with green points
plt.show()

print(best_loss,best_m,best_b)
# Out:
# 3.583001734516836 3.030303030303031 1.0101010101010104

# %%
np.sum((y_guess - Y)**2) # this is how we square it to get rid of the minus signs and them how we add the numbers up
# Out:
# 3.583001734516836

# %%
loss = np.sum((y_guess - Y)**2)

# %%
from re import M
best_loss_so_far = 10000000000

m_best=0
b_best=0

for m_guess in np.linspace(-100,100,100): # this helps us with our guessing approximation
    for b_guess in np.linspace(-100,100,100):
       
        y_guess = m_guess * X + b_guess

        loss = np.sum((y_guess - Y)**2)


        if loss < best_loss_so_far: 
          m_best = m_guess
          b_best = b_guess
          best_loss_so_far = loss 


print("Found best fit:") # this is what titles the approximation, putting these at the end without indentation makes it so it only gives us 3 numbers 
print(m_best, b_best, loss) # this is what shows us what the best fits for each of them are
# Out:
# Found best fit:
# 3.030303030303031 1.0101010101010104 7378517.0

# %% [markdown]
# Plot the line of best fit:
#
# Use blue dots for the collected data and a red line for the estimate.

# %%
plt.title('Linear Fit of Circles') # this makes a graph with the points that are suppossed to go together with the line

plt.xlabel('Diameter')
plt.ylabel('Circumference')

# Plot the collected data
plt.plot(X,Y,'.', label='Observations')

y_estimate = 1

# Plot the line of best fit
plt.plot(X,y_guess,'r-', label=f'Estimate: $y = {best_b} x + {best_m}$')

plt.legend();

# %% [markdown]
# The estimated relationship is:
#
# $y = 3 x + 1$

# %% [markdown]
# ## Part 3: Interpretation
#
# Answer the questions in text cells

# %% [markdown]
# #### Question 1:
#
# What do $m$ and $b$ represent in these equations?

# %% [markdown]
# In these equations m represents the slope and b represent the y-intercept, or where the line starts in the graph

# %% [markdown]
# #### Question 2:
#
# Guess what the correct values $m$ and $b$ should be.

# %% [markdown]
# The correct values of m and b should be, 3 for m and 1 for b

# %% [markdown]
# #### Question 3:
#
# Does it make sense to include $b$ in the parameters?

# %% [markdown]
# It makes sense to include b in the parameters because it is part of the equation of the slope therefore it is needed for everything to work and where the line will start

# %% [markdown]
# ## Bonus:
#
# These problems are extra credit. You may use any resources, but be sure to explain your code.

# %% [markdown]
# #### Bonus 1: Plot the squared errors from your line of best fit

# %%
plt.title("Fit Errors")

plt.xlabel("Diameter")
plt.ylabel("Squared Error")

squared_error = ...

plt.plot(..., 'b.', label = "Errors")

plt.legend();

# %% [markdown]
# #### Bonus 2: Plot the errors as a histogram

# %%
plt.title("Errors")

...

# %% [markdown]
# What distribution does this histogram look like?

# %% [markdown]
# #### Bonus 3: Find the circle with the largest error.
# Hint: use np.max

# %%
largest_error = ...

# %% [markdown]
# #### Bonus 4: Remove the circles with the 2 largest errors and run the fit again.

# %%
...

# %% [markdown]
# What is the difference in your error?

# %% [markdown]
# #### Bonus 5: Find and explain a better method of fitting this data
