# %% [markdown]
# <a href="https://colab.research.google.com/github/juancmq/stats2023/blob/main/Monsalve_Stats_2023_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4]) #the numbers are the data

# %%
# population

# %%
np.sum(x)
# Out:
# 10

# %%
x.shape[0]
# Out:
# 4

# %%
np.sum(x)/x.shape[0]
# Out:
# 2.5

# %%
def mean(x):
    return np.sum(x)/x.shape[0] #shape will give us how many numbers we have on the list

# %%
mean(x) #this will give us the mean of the numbers
# Out:
# 2.5

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
x - mean(x) #we can do multiple equations once we define words
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
(x - mean(x))**2
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
 def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 2.5

# %%
var(x)
# Out:
# 1.25

# %%
std(x)
# Out:
# 1.118033988749895

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,)

# %%
x = (m * x + b) % n # % does division while only keeping the remainder

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x

# %%
X
# Out:
# array([52101., 40966., 57822., ..., 41114.,  3385., 57338.])

# %%
X /= np.max(X)

# %%
plt.plot(X[:100],'.') #this is how we graph a more scattered graph

# %%
plt.hist(X); # this is how we graph a uniform distribution

# %%
plt.hist(X,100); # there are many ways to graph different distributions

# %%
X
# Out:
# array([0.7950103 , 0.62510109, 0.88230716, ..., 0.62735943, 0.05165179,
#        0.8749218 ])

# %%
X
# Out:
# array([0.7950103 , 0.62510109, 0.88230716, ..., 0.62735943, 0.05165179,
#        0.8749218 ])

# %%
X
# Out:
# array([0.7950103 , 0.62510109, 0.88230716, ..., 0.62735943, 0.05165179,
#        0.8749218 ])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)

# %%
X
# Out:
# array([0.57918935, 0.91536917, 0.89615109, ..., 0.12429131, 0.96343893,
#        0.27501397])

# %%
plt.hist(X,100);

# %%
np.random.random()
# Out:
# 0.39971568421683024

# %%
r = np.random.random()

# %%
r
# Out:
# 0.15176004220596517

# %%
r = np.random.randint(1,10)

# %%
r
# Out:
# 8

# %%
r = np.random.randint(0,3,size=(1))

# %%
r[0]
# Out:
# 2

# %%
game = ['rock', 'paper', 'scissors'] # here we will try recreating rock, paper sissors

# %%
game[r[0]] # this will give us one random of our previous threee choices
# Out:
# 'scissors'

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]

# %%
p1,p2
# Out:
# (2, 0)

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
game[p1],game[p2] # this will give us two random choices of the 3 that were above
# Out:
# ('scissors', 'rock')

# %%
import numpy as np

# %%
np.random.randn()
# Out:
# -0.20435986368037312

# %%
numbers  = np.random.randn(2,4)

# %%
numbers.shape
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1)

# %%
numbers.shape
# Out:
# (8,)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
numbers = np.random.randn(100000,)

# %%
numbers.shape
# Out:
# (100000,)

# %%
plt.hist(numbers,100); #another way to scatter the points in a graph is like a wave

# %%
numbers = np.random.rand(1000000,)

# %%
plt.hist(numbers,100);

# %%
np.random.seed(12345) # this is how we can do 4 different types of graphs at the same time
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1)
plt.hist(data[0]) #this will give us the bar graph

plt.subplot(2,2,2)
plt.scatter(data[0], data[1]) # this will give us thescattered points

plt.subplot(2,2,3)
plt.plot(data[0], data[1]) # this will graph lines

plt.subplot(2,2,4)
plt.hist2d(data[0], data[1]) # this will graph a series of squares

plt.show()

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000)

# %%
plt.hist(x);

# %%
x = np.random.rand(1000,)

# %%
plt.hist(x**2); #another way to make a bar graph

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %%
bins
# Out:
# array([ 47.67401067,  58.75290006,  69.83178945,  80.91067884,
#         91.98956823, 103.06845762, 114.14734702, 125.22623641,
#        136.3051258 , 147.38401519, 158.46290458])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y) # this has the ability to graph a single line across the whole of the graph

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y) # this is how we graph a line while at the same time we graph bars

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 100.08288406198832

# %%
std(x)
# Out:
# 14.975014354444243

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100)
y = 2.71**(-x**2)
plt.plot(x,y)

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,1000)

# %%
mu = 0

# %%
sigma = 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
plt.plot(x,y,'g.') # this will make the graph with green points
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-f2f3b2f326bc> in <module>
#       1 plt.plot(x,pdf,'.')
# ----> 2 plt.plot(x,y,'g.') # this will make the graph with green points
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)

# %%
plt.plot(x,cdf,'.');

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.'); # the past 3 are examples of lines we are able to graph

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1)
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3))

# %%
z
# Out:
# array([[[143,  35, 173]]])

# %%
z = np.random.randint(0,255,size=(10,10,3))

# %%
plt.imshow(z) #this will cause a graph with different colored squares

# %%
z = np.zeros((10,10,3))

# %%
z.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(z) # this will give us the color black in the graph

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z) #this will give us a blank graph
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z) # following rgb this means the graph will be red

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z) # same thing following rgb in this case will give us a green graph

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z) # same as the previous tow rgb in this case will give us a blue graph

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2)
# Out:
# (array([  7.,  37., 123., 236., 271., 208.,  87.,  29.,   1.,   1.]),
#  array([-0.01460643,  0.10288311,  0.22037265,  0.3378622 ,  0.45535174,
#          0.57284128,  0.69033082,  0.80782037,  0.92530991,  1.04279945,
#          1.16028899]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100):
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z); # we can play around with different numbers to get different colors
# Out:
# 0.3788749202797582 0.5677372186711952 0.6320131327575037
# 0.2863290964795784 0.4385684935424628 0.6093621854664142
# 0.42953253071812675 0.526425173862869 0.5682287729374794
# 0.6126694224561704 0.2489322765510371 0.3794802902202256
# 0.5178185399936625 0.4774006268221018 0.38608394374710997
# 0.4014516850431995 0.7010598557602025 0.4933869889939871
# 0.32292126969765345 0.4363211416990741 0.5944738656028732
# 0.19595810659461688 0.5955070628173366 0.44316020543688095
# 0.49782428732327466 0.31219035694160524 0.773280779510416
# 0.40626417944264304 0.6283135140355296 0.6147527428582161
# 0.5598360231857235 0.15346565405812967 0.4007727769462227
# 0.5826128803225742 0.5378896523043983 0.24582227443595844
# 0.38986625516742085 0.5300439507399591 0.5949300440635364
# 0.4933616807593659 0.5250794824329102 0.3225760849451149
# 0.5705252856368072 0.5870407513224782 0.6351519234898468
# 0.4701197076573572 0.47480207381767553 0.5234506586404613
# ...

# %%
for i in range(100):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show() # we are able to make different color graphs at the same time
# Out:
# 0.10360189542018527 0.603593480123266 0.23287848434770164
# 0.7161175813153495 0.651172805076479 0.06394572692418588
# 0.034598171137424694 0.5111768997623222 0.10743649182538129
# 0.9721979903719349 0.9337217335991228 0.9377709447343364
# 0.16950147291708972 0.4786800285729802 0.2752816937404513
# 0.389427811325718 0.3859859494764871 0.8191853251484558
# 0.2762416625789108 0.5089262029566818 0.08514657396854797
# 0.45748882100015986 0.05809132042940357 0.8428904341071543
# 0.2185390552355957 0.932190055875245 0.05565800137205423
# 0.24959745013610568 0.7848868052199087 0.778550097337575
# 0.07829024799385342 0.11916496310394986 0.0064737175328611896
# 0.8284148132162961 0.1714925301112451 0.2542727751992593
# 0.9510076118723019 0.46265276390432575 0.9084443349442021
# 0.11774617228828022 0.5244667294813192 0.36685226916103375
# 0.45758275673726934 0.5671885541099669 0.6410184964320075
# 0.43416559805121646 0.754656429649745 0.18210836833494204
# ...

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show() # while we can make multiple colored graphs is a row we can also put them next to one another

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show() # just like the previous graphs we are also able to make multiple at the same time

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show() #just like we can have multiple colors next to one another we are also able to have 2

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show() # we are also able to make different types of graphs with these color palettes

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
